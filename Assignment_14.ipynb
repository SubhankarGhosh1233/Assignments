# %% [markdown]
# # Assignment_14

# %% [markdown]
# ### 1. What does RGBA stand for?

# %% [markdown]
# Ans: RGBA stands for Red-Green-Blue-Alpha.

# %% [markdown]
# ### 2. From the Pillow module, how do you get the RGBA value of any images?

# %% [markdown]
# Ans:
# pip install Pillow
# from PIL import Image
# imgobj = Image.open('F:\INEURON SUBHANKAR\Assignment\Python\google-rainbow-texture-1491566442.jpg')
# pixels = imgobj.convert('RGBA')
# data = imgobj.getdata()
# lofpixels = []
# for pixel in data:
#     lofpixels.extend(pixel)
# lofpixels

# %% [markdown]
# ### 3. What is a box tuple, and how does it work?

# %% [markdown]
# Ans:
#     The box.tuple submodule provides read-only access for the tuple userdata type. It allows, for a single tuple, selective retrieval of the field contents, retrieval of information about size, iteration over all the fields.

# %% [markdown]
# ### 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from PIL import Image
filepath = 'F:\INEURON SUBHANKAR\Assignment\Python\google-rainbow-texture-1491566442.jpg'
img = Image.open(filepath)
width = img.width
height = img.height
print("The height of the image is: ", height)
print("The width of the image is: ", width)
# Out:
# The height of the image is:  300
# The width of the image is:  640

# %% [markdown]
# ### 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %% [markdown]
# Ans:

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x300 at 0x12803217190>

# %%
imgCropped = img.crop(box= (20,20,100,100))
imgCropped.show()

# %% [markdown]
# ### 6. After making changes to an Image object, how could you save it as an image file?

# %% [markdown]
# Ans:

# %%
imgCropped.save("google.jpg")

# %% [markdown]
# ### 7. What module contains Pillow’s shape-drawing code?

# %% [markdown]
# Ans: ImageDraw module contains Pillow’s shape-drawing code.

# %% [markdown]
# ### 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %% [markdown]
# Ans: ImageDraw can do.By the  this code I get this:
#         from PIL import Image, ImageDraw
